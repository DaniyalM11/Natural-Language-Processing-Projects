# %% [markdown]
# ##### CS 583 Assignment 2
# ##### by Daniyal Mufti
# ##### Character Level Neural Machine Translation - English to Pig Latin
# ##### Model 1 - Using a Sequence to Sequence LSTM Encoder Decoder Model

# %% [markdown]
# ### 1. Setup

# %%
#Import Libraries and Dependecies
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import LSTM, Dropout, Dense, Embedding, Bidirectional, Add, Concatenate, Dropout
from tensorflow.keras import Input, Model

# %%
# Set hyperparamters
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = "data.txt"

# %% [markdown]
# ### 2. Vectorize Data

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text = line.split(" ")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = " " + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])
#print(input_token_index)
#print(target_token_index)

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index["'"]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 6510
# Number of unique input tokens: 40
# Number of unique output tokens: 42
# Max sequence length for inputs: 18
# Max sequence length for outputs: 24

# %% [markdown]
# ### 3. Build the LSTM Encoder Decoder Model

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)


# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 40)]   0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None, 42)]   0
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 256), (None, 304128      input_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, None, 256),  306176      input_2[0][0]
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 42)     10794       lstm_1[0][0]
# ==================================================================================================
# Total params: 621,098
# Trainable params: 621,098
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### 4. Compile and Fit Model

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2sAM1")
# Out:
# Epoch 1/100
# 82/82 [==============================] - 14s 14ms/step - loss: 1.4884 - accuracy: 0.5959 - val_loss: 1.2631 - val_accuracy: 0.6706
# Epoch 2/100
# 82/82 [==============================] - 1s 9ms/step - loss: 1.1044 - accuracy: 0.6919 - val_loss: 1.0035 - val_accuracy: 0.7115
# Epoch 3/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.9207 - accuracy: 0.7297 - val_loss: 0.8853 - val_accuracy: 0.7370
# Epoch 4/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.8247 - accuracy: 0.7561 - val_loss: 0.7720 - val_accuracy: 0.7744
# Epoch 5/100
# 82/82 [==============================] - 1s 10ms/step - loss: 0.7562 - accuracy: 0.7774 - val_loss: 0.7527 - val_accuracy: 0.7778
# Epoch 6/100
# 82/82 [==============================] - 1s 10ms/step - loss: 0.7025 - accuracy: 0.7919 - val_loss: 0.7045 - val_accuracy: 0.7920
# Epoch 7/100
# 82/82 [==============================] - 1s 8ms/step - loss: 0.6545 - accuracy: 0.8048 - val_loss: 0.6334 - val_accuracy: 0.8124
# Epoch 8/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.6094 - accuracy: 0.8174 - val_loss: 0.6380 - val_accuracy: 0.8084
# Epoch 9/100
# 82/82 [==============================] - 1s 10ms/step - loss: 0.5720 - accuracy: 0.8288 - val_loss: 0.5688 - val_accuracy: 0.8290
# Epoch 10/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.5273 - accuracy: 0.8426 - val_loss: 0.5690 - val_accuracy: 0.8291
# Epoch 11/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.4792 - accuracy: 0.8558 - val_loss: 0.4883 - val_accuracy: 0.8548
# Epoch 12/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.4303 - accuracy: 0.8696 - val_loss: 0.4681 - val_accuracy: 0.8591
# Epoch 13/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.3858 - accuracy: 0.8807 - val_loss: 0.4509 - val_accuracy: 0.8629
# Epoch 14/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.3479 - accuracy: 0.8928 - val_loss: 0.4025 - val_accuracy: 0.8754
# Epoch 15/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.3133 - accuracy: 0.9025 - val_loss: 0.3720 - val_accuracy: 0.8826
# Epoch 16/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.2849 - accuracy: 0.9110 - val_loss: 0.3468 - val_accuracy: 0.8915
# Epoch 17/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.2582 - accuracy: 0.9187 - val_loss: 0.3071 - val_accuracy: 0.9036
# Epoch 18/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.2352 - accuracy: 0.9260 - val_loss: 0.2646 - val_accuracy: 0.9173
# Epoch 19/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.2105 - accuracy: 0.9332 - val_loss: 0.2875 - val_accuracy: 0.9100
# Epoch 20/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.1939 - accuracy: 0.9384 - val_loss: 0.2499 - val_accuracy: 0.9196
# Epoch 21/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.1768 - accuracy: 0.9444 - val_loss: 0.2419 - val_accuracy: 0.9221
# Epoch 22/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.1583 - accuracy: 0.9500 - val_loss: 0.2135 - val_accuracy: 0.9323
# Epoch 23/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.1460 - accuracy: 0.9542 - val_loss: 0.2148 - val_accuracy: 0.9303
# Epoch 24/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.1304 - accuracy: 0.9587 - val_loss: 0.2279 - val_accuracy: 0.9286
# Epoch 25/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.1215 - accuracy: 0.9623 - val_loss: 0.1797 - val_accuracy: 0.9429
# Epoch 26/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.1084 - accuracy: 0.9664 - val_loss: 0.2363 - val_accuracy: 0.9268
# Epoch 27/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0973 - accuracy: 0.9709 - val_loss: 0.2230 - val_accuracy: 0.9308
# Epoch 28/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0895 - accuracy: 0.9727 - val_loss: 0.1823 - val_accuracy: 0.9417
# Epoch 29/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0788 - accuracy: 0.9767 - val_loss: 0.1752 - val_accuracy: 0.9440
# Epoch 30/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0736 - accuracy: 0.9783 - val_loss: 0.1541 - val_accuracy: 0.9520
# Epoch 31/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0635 - accuracy: 0.9820 - val_loss: 0.1826 - val_accuracy: 0.9455
# Epoch 32/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0598 - accuracy: 0.9827 - val_loss: 0.1530 - val_accuracy: 0.9521
# Epoch 33/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0535 - accuracy: 0.9851 - val_loss: 0.1841 - val_accuracy: 0.9455
# Epoch 34/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0491 - accuracy: 0.9864 - val_loss: 0.1782 - val_accuracy: 0.9480
# Epoch 35/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0443 - accuracy: 0.9879 - val_loss: 0.1552 - val_accuracy: 0.9540
# Epoch 36/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0400 - accuracy: 0.9894 - val_loss: 0.1551 - val_accuracy: 0.9553
# Epoch 37/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0377 - accuracy: 0.9903 - val_loss: 0.1358 - val_accuracy: 0.9614
# Epoch 38/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0331 - accuracy: 0.9915 - val_loss: 0.1518 - val_accuracy: 0.9569
# Epoch 39/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0304 - accuracy: 0.9924 - val_loss: 0.1534 - val_accuracy: 0.9581
# Epoch 40/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0286 - accuracy: 0.9929 - val_loss: 0.1644 - val_accuracy: 0.9565
# Epoch 41/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0255 - accuracy: 0.9936 - val_loss: 0.1579 - val_accuracy: 0.9566
# Epoch 42/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0245 - accuracy: 0.9940 - val_loss: 0.1215 - val_accuracy: 0.9668
# Epoch 43/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0214 - accuracy: 0.9949 - val_loss: 0.1433 - val_accuracy: 0.9605
# Epoch 44/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0213 - accuracy: 0.9950 - val_loss: 0.1146 - val_accuracy: 0.9682
# Epoch 45/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0184 - accuracy: 0.9959 - val_loss: 0.1630 - val_accuracy: 0.9579
# Epoch 46/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0185 - accuracy: 0.9958 - val_loss: 0.1505 - val_accuracy: 0.9595
# Epoch 47/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0175 - accuracy: 0.9961 - val_loss: 0.1339 - val_accuracy: 0.9639
# Epoch 48/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0163 - accuracy: 0.9963 - val_loss: 0.1338 - val_accuracy: 0.9651
# Epoch 49/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0148 - accuracy: 0.9968 - val_loss: 0.1836 - val_accuracy: 0.9520
# Epoch 50/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0135 - accuracy: 0.9971 - val_loss: 0.1472 - val_accuracy: 0.9613
# Epoch 51/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0146 - accuracy: 0.9967 - val_loss: 0.1845 - val_accuracy: 0.9507
# Epoch 52/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0128 - accuracy: 0.9969 - val_loss: 0.1192 - val_accuracy: 0.9684
# Epoch 53/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0114 - accuracy: 0.9975 - val_loss: 0.1280 - val_accuracy: 0.9673
# Epoch 54/100
# 82/82 [==============================] - 1s 10ms/step - loss: 0.0112 - accuracy: 0.9976 - val_loss: 0.1279 - val_accuracy: 0.9669
# Epoch 55/100
# 82/82 [==============================] - 1s 8ms/step - loss: 0.0115 - accuracy: 0.9972 - val_loss: 0.1361 - val_accuracy: 0.9648
# Epoch 56/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0111 - accuracy: 0.9974 - val_loss: 0.1547 - val_accuracy: 0.9604
# Epoch 57/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0111 - accuracy: 0.9976 - val_loss: 0.1232 - val_accuracy: 0.9681
# Epoch 58/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0091 - accuracy: 0.9980 - val_loss: 0.1178 - val_accuracy: 0.9692
# Epoch 59/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0093 - accuracy: 0.9979 - val_loss: 0.1241 - val_accuracy: 0.9677
# Epoch 60/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0096 - accuracy: 0.9978 - val_loss: 0.1350 - val_accuracy: 0.9655
# Epoch 61/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0082 - accuracy: 0.9982 - val_loss: 0.1102 - val_accuracy: 0.9720
# Epoch 62/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0084 - accuracy: 0.9981 - val_loss: 0.1524 - val_accuracy: 0.9622
# Epoch 63/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0072 - accuracy: 0.9984 - val_loss: 0.1318 - val_accuracy: 0.9678
# Epoch 64/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0074 - accuracy: 0.9982 - val_loss: 0.1361 - val_accuracy: 0.9661
# Epoch 65/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0079 - accuracy: 0.9981 - val_loss: 0.1108 - val_accuracy: 0.9734
# Epoch 66/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0068 - accuracy: 0.9986 - val_loss: 0.1140 - val_accuracy: 0.9711
# Epoch 67/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.1383 - val_accuracy: 0.9650
# Epoch 68/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0074 - accuracy: 0.9983 - val_loss: 0.1137 - val_accuracy: 0.9719
# Epoch 69/100
# 82/82 [==============================] - 1s 8ms/step - loss: 0.0060 - accuracy: 0.9988 - val_loss: 0.1729 - val_accuracy: 0.9595
# Epoch 70/100
# 82/82 [==============================] - 1s 8ms/step - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.1436 - val_accuracy: 0.9651
# Epoch 71/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0061 - accuracy: 0.9987 - val_loss: 0.1532 - val_accuracy: 0.9656
# Epoch 72/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0061 - accuracy: 0.9987 - val_loss: 0.1370 - val_accuracy: 0.9653
# Epoch 73/100
# 82/82 [==============================] - 1s 8ms/step - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.1285 - val_accuracy: 0.9706
# Epoch 74/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.1142 - val_accuracy: 0.9725
# Epoch 75/100
# 82/82 [==============================] - 1s 8ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.1150 - val_accuracy: 0.9721
# Epoch 76/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0052 - accuracy: 0.9988 - val_loss: 0.1269 - val_accuracy: 0.9696
# Epoch 77/100
# 82/82 [==============================] - 1s 8ms/step - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.1386 - val_accuracy: 0.9689
# Epoch 78/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.1091 - val_accuracy: 0.9747
# Epoch 79/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.1147 - val_accuracy: 0.9732
# Epoch 80/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.1160 - val_accuracy: 0.9729
# Epoch 81/100
# 82/82 [==============================] - 1s 8ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.1502 - val_accuracy: 0.9674
# Epoch 82/100
# 82/82 [==============================] - 1s 8ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.1111 - val_accuracy: 0.9738
# Epoch 83/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.1122 - val_accuracy: 0.9727
# Epoch 84/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.1637 - val_accuracy: 0.9646
# Epoch 85/100
# 82/82 [==============================] - 1s 10ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.1146 - val_accuracy: 0.9722
# Epoch 86/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.1172 - val_accuracy: 0.9732
# Epoch 87/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.1177 - val_accuracy: 0.9738
# Epoch 88/100
# 82/82 [==============================] - 1s 10ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.1136 - val_accuracy: 0.9740
# Epoch 89/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.1186 - val_accuracy: 0.9728
# Epoch 90/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.1092 - val_accuracy: 0.9745
# Epoch 91/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.1114 - val_accuracy: 0.9743
# Epoch 92/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.1177 - val_accuracy: 0.9736
# Epoch 93/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.1174 - val_accuracy: 0.9737
# Epoch 94/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.1058 - val_accuracy: 0.9758
# Epoch 95/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.1159 - val_accuracy: 0.9737
# Epoch 96/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 0.1288 - val_accuracy: 0.9707
# Epoch 97/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.1072 - val_accuracy: 0.9766
# Epoch 98/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.1106 - val_accuracy: 0.9758
# Epoch 99/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.1184 - val_accuracy: 0.9733
# Epoch 100/100
# 82/82 [==============================] - 1s 9ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.1208 - val_accuracy: 0.9732
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: s2sAM1\assets
# INFO:tensorflow:Assets written to: s2sAM1\assets

# %% [markdown]
# ### 5. Build Inference Model

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2sAM1")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,))
decoder_state_input_c = keras.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# %% [markdown]
# ### 6. Decode Some Sample Sequences

# %%
# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index[" "]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(30):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: apprehensive
# Decoded sentence: apprehensiveway
#
# -
# Input sentence: desperately
# Decoded sentence: esperatelyday
#
# -
# Input sentence: grew
# Decoded sentence: ewgray
#
# -
# Input sentence: niggardly
# Decoded sentence: iggardlynay
#
# -
# Input sentence: brought
# Decoded sentence: oughtbray
#
# -
# Input sentence: imagery
# Decoded sentence: imageryway
#
# -
# Input sentence: quicker
# Decoded sentence: ickerquay
#
# -
# Input sentence: for
# Decoded sentence: orfay
#
# -
# Input sentence: emergency
# Decoded sentence: emergencyway
#
# -
# Input sentence: felt
# Decoded sentence: eltfay
#
# -
# Input sentence: informing
# Decoded sentence: informingway
#
# -
# Input sentence: withdrawn
# Decoded sentence: ithdrawnway
#
# -
# Input sentence: bond-street
# Decoded sentence: ondbay-eetstray
#
# -
# Input sentence: along
# Decoded sentence: alongway
#
# -
# Input sentence: drove
# Decoded sentence: ovedray
#
# -
# Input sentence: observant
# Decoded sentence: observantway
#
# -
# Input sentence: bluntly
# Decoded sentence: untlyblay
#
# -
# Input sentence: gratitude
# Decoded sentence: atitudegray
#
# -
# Input sentence: carefulness
# Decoded sentence: arefulnesscay
#
# -
# Input sentence: tiled
# Decoded sentence: iledtay
#
# -
# Input sentence: grieving
# Decoded sentence: ievinggray
#
# -
# Input sentence: hysterical
# Decoded sentence: ystericalhay
#
# -
# Input sentence: officious
# Decoded sentence: officiousway
#
# -
# Input sentence: preference
# Decoded sentence: eferencepray
#
# -
# Input sentence: reverie
# Decoded sentence: everieray
#
# -
# Input sentence: enthusiastic
# Decoded sentence: enthusiasticway
#
# -
# Input sentence: hastened
# Decoded sentence: astenedhay
#
# -
# Input sentence: cheerful
# Decoded sentence: eerfulchay
#
# -
# Input sentence: ecstasy
# Decoded sentence: ecstasyway
#
# -
# Input sentence: talents
# Decoded sentence: alentstay
